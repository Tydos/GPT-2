# %%
# !git clone https://github.com/Tydos/GPT-2.git
# Out:
# fatal: destination path 'GPT-2' already exists and is not an empty directory.

# %%
cd GPT-2
# Out:
# /content/GPT-2

# %%
# check cuda 
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# print cofiguration 
# !cat src/config.py
# Out:
# import os
#
# DATA_URL = "https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/main/ch02/01_main-chapter-code/the-verdict.txt"
# OUTPUT_DIR = os.path.join(os.path.dirname(__file__), "..", "artifacts")
# DATASET_PATH = os.path.join(OUTPUT_DIR, "dataset.txt")
# CONTEXT_WINDOW_SIZE = 64  # how many tokens are sent for training
# VOCAB_SIZE = 50257  # based on the tokenizer
# CONTEXT_LENGTH = 1024  # how much back can my model read
# BATCH_SIZE = 10  # pytorch dataloader batching
# STRIDE = 1  # overlap between windows
# EMBED_DIM = 768  # number of dimensions
# HEAD_DIM = 64  # GPT-2 always uses head_dim=64
# NUM_HEADS = 12  # embed_dim / head_dim = 128 / 64
# DROP_RATE = 0.0  # dropout rate
# N_LAYER = 12  # number of repeated transformers
# NUM_EPOCHS = 1  # model training epochs

# %%
# !python train.py
# Out:
# INFO: Loading data...
# INFO:   20,479 chars loaded
# INFO:   Train batches: 455 | Val batches: 47
# INFO:   Model: 155,922,432 params | device: cuda
# INFO: Starting training for 1 epochs...
#
# INFO:   Epoch 1/1 | batch 50/455 | loss=4.6308
# INFO:   Epoch 1/1 | batch 100/455 | loss=2.3639
# INFO:   Epoch 1/1 | batch 150/455 | loss=1.2916
# INFO:   Epoch 1/1 | batch 200/455 | loss=0.4443
# INFO:   Epoch 1/1 | batch 250/455 | loss=0.2376
# INFO:   Epoch 1/1 | batch 300/455 | loss=0.1770
# INFO:   Epoch 1/1 | batch 350/455 | loss=0.1305
# INFO:   Epoch 1/1 | batch 400/455 | loss=0.1269
# INFO:   Epoch 1/1 | batch 450/455 | loss=0.1021
# INFO: Epoch  1/1 | train=1.4397 | val=7.1964
# INFO:   Sample: Gisburn had a curious smile in his eyes.
#
# "Oh, I knew him, and he knew me--only it
#
# INFO: Saved model

# %%
from google.colab import files
files.download("artifacts/model.pth")
