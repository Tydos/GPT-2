# %% [markdown]
# ### Full Model Training
#
# This script runs the whole GPT2 architecture on a colab notebook (A100) and saves models to google drive

# %%
# !git clone https://github.com/Tydos/GPT-2.git
# Out:
# Cloning into 'GPT-2'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 139 (delta 68), reused 105 (delta 39), pack-reused 0 (from 0)
# Receiving objects: 100% (139/139), 24.07 MiB | 17.32 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
# %cd GPT-2
# Out:
# /content/GPT-2

# %%
# check cuda 
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# %pip install -r requirements.txt

# %%
# !python main.py --gpu --tokenizer tiktoken --data-url https://dgoldberg.sdsu.edu/515/harrypotter.txt
# Out:
# INFO: Loading data...
# INFO:   442,745 chars loaded
# INFO:   Train batches: 100 | Val batches: 11
# INFO:   Model: 155,922,432 params | device: cuda
# INFO: Starting training for 10 epochs...
#
# INFO:   Epoch 1/10 | batch 50/100 | loss=5.3413
# INFO:   Epoch 1/10 | batch 100/100 | loss=4.6057
# INFO: Epoch  1/10 | train=5.6332 | val=4.9552
# INFO:   Sample: Gisburn had a evil smile, and a large, and the first time.
#
# "I'm not to be in the first
#
# INFO:   Epoch 2/10 | batch 50/100 | loss=3.9895
# INFO:   Epoch 2/10 | batch 100/100 | loss=3.6632
# INFO: Epoch  2/10 | train=4.0026 | val=4.7582
# INFO:   Sample: Gisburn had a evil smile, and a large pink umbrella and they were a bit o'clock the door.
#
# "I
#
# INFO:   Epoch 3/10 | batch 50/100 | loss=3.2257
# INFO:   Epoch 3/10 | batch 100/100 | loss=2.8198
# INFO: Epoch  3/10 | train=3.1121 | val=4.8985
# INFO:   Sample: Gisburn had a evil smile, and a long black hair, and it, and it was a large box of the house.
#
#
# INFO:   Epoch 4/10 | batch 50/100 | loss=1.9161
# INFO:   Epoch 4/10 | batch 100/100 | loss=1.2867
# INFO: Epoch  4/10 | train=1.9153 | val=5.5092
# INFO:   Sample: Gisburn had a evil smile, and they were sure they were looking forward to see what they were so much.
#
# Harry was
#
# INFO:   Epoch 5/10 | batch 50/100 | loss=0.4786
# INFO:   Epoch 5/10 | batch 100/100 | loss=0.2328
# INFO: Epoch  5/10 | train=0.5404 | val=6.2704
# INFO:   Sample: Gisburn had a evil smile, and the other day of gold letters spelled words in a week before he'd heard.
#
# "
#
# INFO:   Epoch 6/10 | batch 50/100 | loss=0.0823
# INFO:   Epoch 6/10 | batch 100/100 | loss=0.0740
# INFO: Epoch  6/10 | train=0.0899 | val=6.6272
# INFO:   Sample: Gisburn had a evil smile, and a long bit of what they were saying, what they were going to get past than Malfoy burst into
#
# INFO:   Epoch 7/10 | batch 50/100 | loss=0.0358
# INFO:   Epoch 7/10 | batch 100/100 | loss=0.0420
# INFO: Epoch  7/10 | train=0.0376 | val=6.7991
# INFO:   Sample: Gisburn had a evil smile, and a nasty shade of wood up its nose, and as though it was very old indeed when he looked
#
# INFO:   Epoch 8/10 | batch 50/100 | loss=0.0283
# INFO:   Epoch 8/10 | batch 100/100 | loss=0.0228
# INFO: Epoch  8/10 | train=0.0257 | val=6.9088
# INFO:   Sample: Gisburn had a evil smile, and a long bit of what they were with a secret, which was talking to him by the old P
#
# INFO:   Epoch 9/10 | batch 50/100 | loss=0.0252
# INFO:   Epoch 9/10 | batch 100/100 | loss=0.0173
# INFO: Epoch  9/10 | train=0.0213 | val=6.9985
# INFO:   Sample: Gisburn had a evil smile, and they had come out for a word --"
#
# "You know what?" said Harry asked
#
# INFO:   Epoch 10/10 | batch 50/100 | loss=0.0164
# INFO:   Epoch 10/10 | batch 100/100 | loss=0.0168
# INFO: Epoch 10/10 | train=0.0191 | val=7.0500
# INFO:   Sample: Gisburn had a evil smile, and they were sure it.
#
# "The problem is it?" said Filch, "we
#
# INFO: Saved model

# %%
# !ls -lh artifacts/model.pth
# Out:
# -rw-r--r-- 1 root root 595M Jun 20 18:01 artifacts/model.pth

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp artifacts/model.pth /content/drive/MyDrive/
# Out:
# Mounted at /content/drive
